# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/augmented-mango-data/practice/README.dataset.txt
# /kaggle/input/augmented-mango-data/practice/README.roboflow.txt
# /kaggle/input/augmented-mango-data/practice/data.yaml
# /kaggle/input/augmented-mango-data/practice/valid/labels/IMG_20211106_135451-Custom-_jpg.rf.065aa4b068f92b3e5bad2767ff6da8a9.txt
# /kaggle/input/augmented-mango-data/practice/valid/labels/IMG_20211106_163815-Custom-_jpg.rf.e1e26515ca4836fe1931fab9ca96dbe7.txt
# /kaggle/input/augmented-mango-data/practice/valid/labels/IMG_20211011_153404-Custom-_jpg.rf.992ea533ec7dadb5f4dfdcd1074f535e.txt
# /kaggle/input/augmented-mango-data/practice/valid/labels/IMG_20211106_140231-Custom-_jpg.rf.fb59f6e95db92baf32608f776827099f.txt
# /kaggle/input/augmented-mango-data/practice/valid/labels/20211231_160353-Custom-_jpg.rf.cd5fec693a08456765b0b1dc2a37490d.txt
# /kaggle/input/augmented-mango-data/practice/valid/labels/IMG_20211011_161616-Custom-_jpg.rf.e8fc8fa2acbc3ac5161f8758ad76ed93.txt
# ...

# %%
# !pip install ultralytics -q

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')

results = model.train(
    data='/kaggle/input/augmented-mango-data/practice/data.yaml',  # Path to your custom YAML file
    epochs=100, # Number of epochs




)
# Out:
# Ultralytics 8.3.71 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val()
# Out:
# Ultralytics 8.3.71 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 218 layers, 25,843,234 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /kaggle/input/augmented-mango-data/practice/valid/labels... 539 images, 2 backgrounds, 0 corrupt: 100%|██████████| 539/539 [00:00<00:00, 542.03it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/augmented-mango-data/practice/valid is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 34/34 [00:16<00:00,  2.12it/s]
#                    all        539       1384      0.816       0.74      0.783       0.58
#            Anthracnose         78        264      0.886      0.798       0.86      0.569
#       Bacterial canker         85        218      0.819      0.697      0.786       0.54
#             Gall Midge        101        426      0.681      0.554      0.579       0.31
# ...

# %%
infer=YOLO('/kaggle/working/runs/detect/train/weights/best.pt')

# %%
infer.predict('/kaggle/input/augmented-mango-data/practice/test/images',save=True,save_txt=True)
# Out:
# image 1/536 /kaggle/input/augmented-mango-data/practice/test/images/20211008_124301-Custom-_jpg.rf.4ffcdd1fb3b5072239d6bc6fc325a4db.jpg: 640x640 2 Anthracnoses, 37.0ms
# image 2/536 /kaggle/input/augmented-mango-data/practice/test/images/20211008_124334-Custom-_jpg.rf.672cb45ecaa61b92c7a4bfdeb98143f8.jpg: 640x640 2 Anthracnoses, 36.3ms
# image 3/536 /kaggle/input/augmented-mango-data/practice/test/images/20211008_124522-Custom-_jpg.rf.2e340b60600ba21f757f90bd442d573e.jpg: 640x640 3 Anthracnoses, 36.2ms
# image 4/536 /kaggle/input/augmented-mango-data/practice/test/images/20211011_133201-Custom-_jpg.rf.150b90fe5a102a21c7aad815598c94a6.jpg: 640x640 6 Anthracnoses, 36.2ms
# image 5/536 /kaggle/input/augmented-mango-data/practice/test/images/20211011_133203-Custom-_jpg.rf.7817190855f01f296c1e44a745f92b59.jpg: 640x640 5 Anthracnoses, 35.6ms
# ...

# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO("runs/detect/train/weights/best.pt")

# Save the model to a new location
model.export(format="torchscript")  # You can also use "onnx" or "engine" for different forma# Copy the model to Google Drive (if using Colab)
# Out:
# Ultralytics 8.3.71 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.00GHz)
# Model summary (fused): 218 layers, 25,843,234 parameters, 0 gradients, 78.7 GFLOPs
#
# PyTorch: starting from 'runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 10, 8400) (148.5 MB)
#
# TorchScript: starting export with torch 2.5.1+cu121...
# TorchScript: export success ✅ 4.7s, saved as 'runs/detect/train/weights/best.torchscript' (99.1 MB)
#
# Export complete (7.8s)
# Results saved to /kaggle/working/runs/detect/train/weights
# Predict:         yolo predict task=detect model=runs/detect/train/weights/best.torchscript imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train/weights/best.torchscript imgsz=640 data=/kaggle/input/augmented-mango-data/practice/data.yaml
# Visualize:       https://netron.app
# 'runs/detect/train/weights/best.torchscript'
